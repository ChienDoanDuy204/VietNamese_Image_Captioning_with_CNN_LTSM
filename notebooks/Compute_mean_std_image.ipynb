# %%
import sys
from pathlib import Path
from datasets import load_dataset

# %%
# Load dataset from hugging face 
dataset = load_dataset("ai-enthusiasm-community/KTVIC")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
dataset['train'][0]
# Out:
# {'image_uid': '000000000001',
#  'caption_uid': ['000000000001_1',
#   '000000000001_2',
#   '000000000001_3',
#   '000000000001_4',
#   '000000000001_5'],
#  'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=695x456>,
#  'caption_vi': ['ba chiếc thuyền đang di chuyển ở trên con sông',
#   'có ba con thuyền đang di chuyển trên con sông',
#   'trên dòng sông có ba con thuyền đang di chuyển',
#   'ba con thuyền đang di chuyển bên một cánh đồng lúa',
#   'ba chiếc thuyền đang chuyển động trên một con sông'],
#  'segment_caption_vi': ['ba chiếc thuyền đang di_chuyển ở trên con sông',
#   'có ba con thuyền đang di_chuyển trên con sông',
#   'trên dòng sông có ba con thuyền đang di_chuyển',
#   'ba con thuyền đang di_chuyển bên một cánh đồng lúa',
#   'ba chiếc thuyền đang chuyển_động trên một con sông']}

# %%
# Thư mục ROOT của project
ROOT_DIR = Path.cwd().parent
ROOT_DIR
# Out:
# WindowsPath('D:/Code Module 6/VietNamese_Image_Captioning_with_CNN_LTSM')

# %%
SOURCE_DIR = ROOT_DIR/'source'
CONFIG_DIR = ROOT_DIR/'configuration'

# %%
sys.path.extend([str(SOURCE_DIR), str(CONFIG_DIR)])

# %%
from preprocessing.preprocessing_img import *

# %%
from organize_data import *

# %%
viCaptioningdataset = VicaptioningDataSet(dataset=dataset, split='train', val_split=0.2, is_shuffle=True)

# %%
viCaptioningdataset[0]
# Out:
# (tensor([[[0.9647, 0.9647, 0.9647,  ..., 0.9686, 0.7686, 0.5922],
#           [0.9647, 0.9647, 0.9647,  ..., 0.9725, 0.8000, 0.5922],
#           [0.9647, 0.9647, 0.9647,  ..., 0.9686, 0.8000, 0.6039],
#           ...,
#           [0.8863, 0.9098, 0.8902,  ..., 0.8667, 0.8667, 0.8627],
#           [0.8471, 0.8824, 0.8627,  ..., 0.8588, 0.8588, 0.8588],
#           [0.8667, 0.8706, 0.8549,  ..., 0.8549, 0.8510, 0.8471]],
#
#          [[0.9843, 0.9843, 0.9843,  ..., 0.9725, 0.7490, 0.5569],
#           [0.9843, 0.9843, 0.9843,  ..., 0.9765, 0.7804, 0.5569],
#           [0.9843, 0.9843, 0.9843,  ..., 0.9725, 0.7843, 0.5686],
#           ...,
#           [0.8353, 0.8745, 0.8667,  ..., 0.8314, 0.8314, 0.8275],
#           [0.8078, 0.8510, 0.8431,  ..., 0.8235, 0.8235, 0.8235],
#           [0.8275, 0.8392, 0.8314,  ..., 0.8196, 0.8157, 0.8118]],
#
#          [[0.9961, 0.9961, 0.9961,  ..., 0.9608, 0.7176, 0.5059],
#           [0.9961, 0.9961, 0.9961,  ..., 0.9647, 0.7451, 0.5059],
#           [0.9961, 0.9961, 0.9961,  ..., 0.9647, 0.7529, 0.5176],
#           ...,
#           [0.7686, 0.8000, 0.7804,  ..., 0.7647, 0.7647, 0.7647],
#           [0.7412, 0.7843, 0.7647,  ..., 0.7569, 0.7569, 0.7569],
#           [0.7608, 0.7725, 0.7529,  ..., 0.7529, 0.7490, 0.7451]]]),
#  'những người đang đi bên ngoài siêu thị đều mặc áo màu đỏ')

# %%
compute = ComputeMeanStd(dataset=viCaptioningdataset, batch_size=1024, num_channels=3)

# %%
mean, std = compute()

# %%
compute.save_mean_std(path=str(CONFIG_DIR/'mean_std_img.json'), mean = mean, std = std)
